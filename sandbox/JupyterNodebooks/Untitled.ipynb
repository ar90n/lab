# %%
import cupy

# %%
dir(cupy)
# Out:
# ['ElementwiseKernel',
#  'MachAr',
#  'ReductionKernel',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_cupy',
#  '_version',
#  'abs',
#  'absolute',
#  'add',
#  'all',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
#  'arctan',
#  'arctan2',
#  'arctanh',
#  'argmax',
#  'argmin',
#  'argpartition',
#  'argsort',
#  'array',
#  'array_repr',
#  'array_split',
#  'array_str',
#  'asanyarray',
#  'asarray',
#  'ascontiguousarray',
#  'asfortranarray',
#  'asnumpy',
#  'atleast_1d',
#  'atleast_2d',
#  'atleast_3d',
#  'base_repr',
#  'binary',
#  'binary_repr',
#  'bincount',
#  'bitwise_and',
#  'bitwise_or',
#  'bitwise_xor',
#  'blackman',
#  'bool_',
#  'broadcast',
#  'broadcast_arrays',
#  'broadcast_to',
#  'byte',
#  'c_',
#  'can_cast',
#  'ceil',
#  'choose',
#  'clear_memo',
#  'clip',
# ...
