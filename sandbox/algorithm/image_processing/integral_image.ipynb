# %%
from  PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
r = requests.get('http://eeweb.poly.edu/~yao/EL5123/image/lena_gray.bmp', stream=True)
img = np.asarray(Image.open(r.raw))
plt.imshow(img, cmap = 'gray')

# %%
plt.imshow(integral_img, cmap='gray')

# %%
box_size = 9
box_blurred = integral_img[box_size:,box_size:] + integral_img[:-box_size,:-box_size] - integral_img[box_size:,:-box_size] - integral_img[:-box_size,box_size:]

# %%
plt.imshow(box_blurred, cmap='gray')
