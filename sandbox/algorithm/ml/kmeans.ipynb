# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
data = iris.data[:,(0,3)]

# %%
minv = np.min(data,axis=0)
maxv = np.max(data,axis=0)
centroid = np.random.rand(2,2) * (maxv - minv) + minv
centroid
# Out:
# array([[ 5.64660644,  1.90345286],
#        [ 5.69764935,  1.53329736]])

# %%
while True:
   clss= np.argmin(np.linalg.norm((np.repeat(data,n, axis=0).reshape((-1,2,2)) - centroid),axis=2),axis=1)
   print(clss.shape)
   print(data.shape)
   centroid, last_centroid = np.array([np.mean(data[clss==0],axis=0),np.mean(data[clss==1],axis=0)]), centroid
   err = np.sum(np.linalg.norm((centroid - last_centroid), axis=1))
   if err < eps:
       break
# Out:
# (225,)
# (150, 2)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-212-8ae9fb2f9556> in <module>()
#       3    print(clss.shape)
#       4    print(data.shape)
# ----> 5    centroid, last_centroid = np.array([np.mean(data[clss==0],axis=0),np.mean(data[clss==1],axis=0)]), centroid
#       6    err = np.sum(np.linalg.norm((centroid - last_centroid), axis=1))
#       7    if err < eps:
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 150 but corresponding boolean dimension is 225

# %%
plt.scatter(data[:,0], data[:,1],c=clss)
